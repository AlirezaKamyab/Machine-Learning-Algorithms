# %% [markdown]
# # Training Data
# In this notebook, we train our neural network

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, Normalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import mnist
from tensorflow.keras.losses import CategoricalCrossentropy, SparseCategoricalCrossentropy

# %% [markdown]
# For binary classification we used Logistic Regression which resulted in 0 or 1 for each input. For multi-class classification we use more general case of logistic regression which is softmax regression.
# In logistic regression we had:

# %% [markdown]
# $
# Z = W\times{X} + B\\
# A = sigmoid(Z)
# $

# %% [markdown]
# and the loss function was BinaryCrossEntropy:

# %% [markdown]
# $
# Loss(a_1, y^{(i)}) = -ylog(a_1)-(1-y)log(1-a_1)
# $ <br>
# as we know $a_0 = 1-a_1$<br>
# $
# Loss(a_1, y^{(i)}) = -ylog(a_1)-(1-y)log(a_0)
# $

# %% [markdown]
# ## Softmax
# For softmax regression we define its function as below
# ### Function

# %% [markdown]
# $
# \begin{equation}
#     Z = W\times{X} + B\\
#     A^{[j]} = \frac{\displaystyle{e^{Z_{j}}}}{\displaystyle\sum_{i=1}^{n}e^{Z_{i}}}
# \end{equation}
# $

# %% [markdown]
# - Above formula shows Softmax equation for $j$th unit and $n$ is the number of classes.
# - In both equations, $X$ is a matrix that its rows identify data and columns identify features.
# - In both equations, $W$ is a matrix that its rows identify features and columns identify units.
# - In both equations, $B$ is a matrix with one row and the number of units, columns identifying intercept for each unit.
# - In both equations, $Z$ is a matrix resulted from $W\times{X}+B$ comprising $m$ rows and $n$ columns. $m$ is the number of data and $n$ is the number of units in that specific layer.
# - In the last equation, $Z_j$ means $j$th column of $Z$.

# %% [markdown]
# ### Loss

# %% [markdown]
# Loss function is like BinaryCrossEntropy but more general one. Loss function for softmax is called CategoricalCrossEntropy which returns one-hot encoded result. Also SparseCategoricalCrossEntropy is one of the losses for softmax which returns an index specifiying the class.

# %% [markdown]
# $
# \begin{equation}
#     Loss(\overrightarrow{a}, y)=
#     \begin{cases}
#         -log(a_0) & if y = 0\\
#         -log(a_1) & if y = 1\\
#         \vdots\\
#         -log(a_{n-1}) & if y = n-1\\
#     \end{cases}
# \end{equation}
# $

# %% [markdown]
# ### Cost
# Cost is the average of all of the Loss functions.

# %% [markdown]
# $
# cost(\overrightarrow{a}, \overrightarrow{y}) = \frac{1}{n}\displaystyle \sum_{i=0}^{n - 1} Loss(a_{i}, y_{i})
# $

# %%
def softmax(z):
    z_exp = np.exp(z)
    result = z_exp / np.sum(z_exp)
    return result

# %%
def loss(a, y):
    return -np.log(a)[y]

# %%
def cost(a, y):
    summation = 0
    for i in range(len(a)):
        summation += loss(a[i], y[i])
    return summation / len(a)

# %% [markdown]
# ## Example
# Train handwritten digits

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
imsize = X_train.shape[1]

# %%
fig, ax = plt.subplots(10, 10, figsize=(15, 15))
cnt=0
for i in ax.flatten():
    i.imshow(X_train[cnt], cmap='gray')
    i.set_title(y_train[cnt])
    i.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    cnt += 1
fig.subplots_adjust(top=1)

# %%
X_train = X_train.reshape(X_train.shape[0], imsize ** 2) # Flattening each image
X_test = X_test.reshape(X_test.shape[0], imsize ** 2) # Flattening each image

# %%
model = Sequential([
    tf.keras.Input(shape=(imsize ** 2, )),
    Dense(units=25, activation='relu', name='layer1'),
    Dense(units=15, activation='relu', name='layer2'),
    Dense(units=10, activation='softmax', name='layer3')
], name='softmax_model')
model.summary()
# Out:
# Model: "softmax_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  layer1 (Dense)              (None, 25)                19625
#
#  layer2 (Dense)              (None, 15)                390
#
#  layer3 (Dense)              (None, 10)                160
#
# =================================================================
# Total params: 20,175
# Trainable params: 20,175
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    loss=SparseCategoricalCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy']
)
norm = Normalization()
norm.adapt(X_train)
Xn_train = norm(X_train)
model.fit(Xn_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 2s 778us/step - loss: 0.3569 - accuracy: 0.8959
# Epoch 2/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.1692 - accuracy: 0.9501
# Epoch 3/50
# 1875/1875 [==============================] - 1s 775us/step - loss: 0.1337 - accuracy: 0.9597
# Epoch 4/50
# 1875/1875 [==============================] - 1s 775us/step - loss: 0.1142 - accuracy: 0.9658
# Epoch 5/50
# 1875/1875 [==============================] - 1s 775us/step - loss: 0.1022 - accuracy: 0.9691
# Epoch 6/50
# 1875/1875 [==============================] - 1s 772us/step - loss: 0.0919 - accuracy: 0.9715
# Epoch 7/50
# 1875/1875 [==============================] - 1s 774us/step - loss: 0.0847 - accuracy: 0.9739
# Epoch 8/50
# 1875/1875 [==============================] - 1s 772us/step - loss: 0.0778 - accuracy: 0.9762
# Epoch 9/50
# 1875/1875 [==============================] - 1s 774us/step - loss: 0.0716 - accuracy: 0.9773
# Epoch 10/50
# 1875/1875 [==============================] - 1s 771us/step - loss: 0.0664 - accuracy: 0.9789
# Epoch 11/50
# 1875/1875 [==============================] - 1s 772us/step - loss: 0.0645 - accuracy: 0.9795
# Epoch 12/50
# 1875/1875 [==============================] - 1s 773us/step - loss: 0.0597 - accuracy: 0.9810
# Epoch 13/50
# 1875/1875 [==============================] - 1s 772us/step - loss: 0.0561 - accuracy: 0.9819
# Epoch 14/50
# 1875/1875 [==============================] - 1s 774us/step - loss: 0.0512 - accuracy: 0.9839
# Epoch 15/50
# 1875/1875 [==============================] - 1s 774us/step - loss: 0.0515 - accuracy: 0.9836
# Epoch 16/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0485 - accuracy: 0.9844
# Epoch 17/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0453 - accuracy: 0.9848
# Epoch 18/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0428 - accuracy: 0.9866
# Epoch 19/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0417 - accuracy: 0.9868
# Epoch 20/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0389 - accuracy: 0.9871
# Epoch 21/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0376 - accuracy: 0.9879
# Epoch 22/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0358 - accuracy: 0.9883
# Epoch 23/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0330 - accuracy: 0.9890
# Epoch 24/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0347 - accuracy: 0.9884
# Epoch 25/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0330 - accuracy: 0.9895
# Epoch 26/50
# 1875/1875 [==============================] - 1s 780us/step - loss: 0.0308 - accuracy: 0.9898
# Epoch 27/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0300 - accuracy: 0.9902
# Epoch 28/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.0284 - accuracy: 0.9910
# Epoch 29/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.0287 - accuracy: 0.9909
# Epoch 30/50
# 1875/1875 [==============================] - 1s 785us/step - loss: 0.0259 - accuracy: 0.9917
# Epoch 31/50
# 1875/1875 [==============================] - 1s 780us/step - loss: 0.0262 - accuracy: 0.9915
# Epoch 32/50
# 1875/1875 [==============================] - 1s 790us/step - loss: 0.0247 - accuracy: 0.9920
# Epoch 33/50
# 1875/1875 [==============================] - 1s 799us/step - loss: 0.0233 - accuracy: 0.9919
# Epoch 34/50
# 1875/1875 [==============================] - 1s 787us/step - loss: 0.0242 - accuracy: 0.9922
# Epoch 35/50
# 1875/1875 [==============================] - 1s 783us/step - loss: 0.0212 - accuracy: 0.9931
# Epoch 36/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0259 - accuracy: 0.9929
# Epoch 37/50
# 1875/1875 [==============================] - 1s 798us/step - loss: 0.0239 - accuracy: 0.9929
# Epoch 38/50
# 1875/1875 [==============================] - 1s 792us/step - loss: 0.0191 - accuracy: 0.9936
# Epoch 39/50
# 1875/1875 [==============================] - 1s 788us/step - loss: 0.0201 - accuracy: 0.9936
# Epoch 40/50
# 1875/1875 [==============================] - 1s 783us/step - loss: 0.0198 - accuracy: 0.9934
# Epoch 41/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.0197 - accuracy: 0.9931
# Epoch 42/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0164 - accuracy: 0.9945
# Epoch 43/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.0185 - accuracy: 0.9938
# Epoch 44/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0177 - accuracy: 0.9939
# Epoch 45/50
# 1875/1875 [==============================] - 1s 776us/step - loss: 0.0164 - accuracy: 0.9946
# Epoch 46/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0184 - accuracy: 0.9939
# Epoch 47/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0159 - accuracy: 0.9949
# Epoch 48/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0195 - accuracy: 0.9937
# Epoch 49/50
# 1875/1875 [==============================] - 1s 781us/step - loss: 0.0175 - accuracy: 0.9942
# Epoch 50/50
# 1875/1875 [==============================] - 1s 782us/step - loss: 0.0186 - accuracy: 0.9944

# %%
predicted = model(norm(X_test)).numpy().argmax(axis=1)

# %%
fig, ax = plt.subplots(10, 20, figsize=(15, 15))
cnt=0
for i in ax.flatten():
    i.imshow(X_test[cnt].reshape(-1, imsize), cmap='gray')
    i.set_title(f"{y_test[cnt]} {predicted[cnt]}")
    i.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    cnt += 1

# %% [markdown]
# First number above each image is the original number and the second one is the predicted number.

# %% [markdown]
# ### Better approach

# %%
model_accurate = Sequential([
    tf.keras.Input(shape=(imsize ** 2)),
    Dense(units=25, activation='relu'),
    Dense(units=15, activation='relu'),
    Dense(units=10, activation='linear')
], name='accurate_softmax')
model_accurate.summary()
# Out:
# Model: "accurate_softmax"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 25)                19625
#
#  dense_1 (Dense)             (None, 15)                390
#
#  dense_2 (Dense)             (None, 10)                160
#
# =================================================================
# Total params: 20,175
# Trainable params: 20,175
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_accurate.compile(
    loss=SparseCategoricalCrossentropy(from_logits=True),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    metrics=['accuracy']
)
model_accurate.fit(Xn_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 2s 786us/step - loss: 0.3513 - accuracy: 0.8958
# Epoch 2/50
# 1875/1875 [==============================] - 1s 766us/step - loss: 0.1704 - accuracy: 0.9504
# Epoch 3/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.1346 - accuracy: 0.9604
# Epoch 4/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.1149 - accuracy: 0.9657
# Epoch 5/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.1014 - accuracy: 0.9686
# Epoch 6/50
# 1875/1875 [==============================] - 1s 768us/step - loss: 0.0927 - accuracy: 0.9711
# Epoch 7/50
# 1875/1875 [==============================] - 1s 758us/step - loss: 0.0832 - accuracy: 0.9743
# Epoch 8/50
# 1875/1875 [==============================] - 1s 758us/step - loss: 0.0777 - accuracy: 0.9761
# Epoch 9/50
# 1875/1875 [==============================] - 1s 758us/step - loss: 0.0713 - accuracy: 0.9778
# Epoch 10/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0661 - accuracy: 0.9790
# Epoch 11/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0624 - accuracy: 0.9803
# Epoch 12/50
# 1875/1875 [==============================] - 1s 765us/step - loss: 0.0584 - accuracy: 0.9813
# Epoch 13/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0556 - accuracy: 0.9824
# Epoch 14/50
# 1875/1875 [==============================] - 1s 757us/step - loss: 0.0516 - accuracy: 0.9839
# Epoch 15/50
# 1875/1875 [==============================] - 1s 757us/step - loss: 0.0502 - accuracy: 0.9841
# Epoch 16/50
# 1875/1875 [==============================] - 1s 756us/step - loss: 0.0465 - accuracy: 0.9854
# Epoch 17/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0444 - accuracy: 0.9861
# Epoch 18/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0424 - accuracy: 0.9864
# Epoch 19/50
# 1875/1875 [==============================] - 1s 762us/step - loss: 0.0404 - accuracy: 0.9873
# Epoch 20/50
# 1875/1875 [==============================] - 1s 763us/step - loss: 0.0383 - accuracy: 0.9872
# Epoch 21/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0369 - accuracy: 0.9888
# Epoch 22/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0359 - accuracy: 0.9888
# Epoch 23/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0346 - accuracy: 0.9885
# Epoch 24/50
# 1875/1875 [==============================] - 1s 762us/step - loss: 0.0317 - accuracy: 0.9898
# Epoch 25/50
# 1875/1875 [==============================] - 1s 762us/step - loss: 0.0315 - accuracy: 0.9895
# Epoch 26/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0297 - accuracy: 0.9905
# Epoch 27/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0297 - accuracy: 0.9900
# Epoch 28/50
# 1875/1875 [==============================] - 1s 766us/step - loss: 0.0290 - accuracy: 0.9908
# Epoch 29/50
# 1875/1875 [==============================] - 1s 763us/step - loss: 0.0288 - accuracy: 0.9905
# Epoch 30/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0278 - accuracy: 0.9909
# Epoch 31/50
# 1875/1875 [==============================] - 1s 767us/step - loss: 0.0234 - accuracy: 0.9926
# Epoch 32/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0295 - accuracy: 0.9906
# Epoch 33/50
# 1875/1875 [==============================] - 1s 758us/step - loss: 0.0247 - accuracy: 0.9918
# Epoch 34/50
# 1875/1875 [==============================] - 1s 765us/step - loss: 0.0228 - accuracy: 0.9925
# Epoch 35/50
# 1875/1875 [==============================] - 1s 779us/step - loss: 0.0248 - accuracy: 0.9918
# Epoch 36/50
# 1875/1875 [==============================] - 1s 786us/step - loss: 0.0208 - accuracy: 0.9934
# Epoch 37/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0219 - accuracy: 0.9926
# Epoch 38/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0238 - accuracy: 0.9926
# Epoch 39/50
# 1875/1875 [==============================] - 1s 764us/step - loss: 0.0209 - accuracy: 0.9932
# Epoch 40/50
# 1875/1875 [==============================] - 1s 780us/step - loss: 0.0273 - accuracy: 0.9929
# Epoch 41/50
# 1875/1875 [==============================] - 1s 778us/step - loss: 0.0257 - accuracy: 0.9923
# Epoch 42/50
# 1875/1875 [==============================] - 1s 777us/step - loss: 0.0184 - accuracy: 0.9947
# Epoch 43/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0196 - accuracy: 0.9937
# Epoch 44/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0187 - accuracy: 0.9940
# Epoch 45/50
# 1875/1875 [==============================] - 1s 762us/step - loss: 0.0176 - accuracy: 0.9938
# Epoch 46/50
# 1875/1875 [==============================] - 1s 759us/step - loss: 0.0171 - accuracy: 0.9946
# Epoch 47/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0173 - accuracy: 0.9945
# Epoch 48/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0171 - accuracy: 0.9944
# Epoch 49/50
# 1875/1875 [==============================] - 1s 761us/step - loss: 0.0137 - accuracy: 0.9954
# Epoch 50/50
# 1875/1875 [==============================] - 1s 763us/step - loss: 0.0206 - accuracy: 0.9935

# %%
logits = model_accurate(Xn_train)
f_x = tf.nn.softmax(logits)

# %%
predicted_logits = model_accurate(norm(X_test))
predicted_fx = tf.nn.softmax(predicted_logits).numpy().argmax(axis=1)

# %%
fig, ax = plt.subplots(10, 20, figsize=(15, 15))
cnt=0
for i in ax.flatten():
    i.imshow(X_test[cnt].reshape(-1, imsize), cmap='gray')
    i.set_title(f"{y_test[cnt]} {predicted[cnt]} {predicted_fx[cnt]}")
    i.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    cnt += 1

# %% [markdown]
#  - First number is the original number, second number is from the first prediction and third number is from the last prediction.<br>
#  Second model, eventhough the roughly the same, but is more accurate and is recommended approach.

# %%
#Find errors
err_1 = []
for i in range(len(X_test)):
    if predicted[i] != y_test[i]: err_1.append(i)
print(f'[1nd approach]: There are {len(err_1)} errors in {len(X_test)} tests.')

err_2 = []
for i in range(len(X_test)):
    if predicted_fx[i] != y_test[i]: err_2.append(i)
print(f'[2nd approach]: There are {len(err_2)} errors in {len(X_test)} tests.')
# Out:
# [1nd approach]: There are 436 errors in 10000 tests.
# [2nd approach]: There are 440 errors in 10000 tests.

# %% [markdown]
# End.
